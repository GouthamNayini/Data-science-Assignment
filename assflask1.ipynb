# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Flask is a micro web framework written in Python. It is lightweight and designed to be simple to use, making it an excellent choice for building web applications and APIs. Some advantages of Flask include:
#
# 1-Lightweight: Flask is a micro-framework, which means it is minimalistic and doesn't have unnecessary layers. This makes it easy to understand and use.
#
# 2-Flexibility: Flask allows developers to choose the components they want to use, rather than imposing a specific structure. This flexibility is advantageous when designing applications.
#
# 3-Easy to Learn: Flask is known for its simplicity and easy learning curve. It provides a quick way to get started with web development in Python.
#
# 4-Widely Used: Flask is widely used and has a large and active community. This means there are many resources, tutorials, and extensions available.
#
# 5-Extensible: Flask is extensible, and developers can add additional libraries or tools as needed for their specific project requirements.
#
# 6-Built-in Development Server: Flask comes with a built-in development server, making it easy to test and develop applications locally.

# %% [markdown]
# Q2. Create a simple Flask application to display 'Hello World!!'. Attach the screenshot of the output in Jupyter Notebook

# %%
from IPython import display

# %%
display.Image("ss19.png")

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
# App routing in Flask refers to the process of defining how the application responds to different HTTP requests. In Flask, the @app.route() decorator is used to bind a function to a URL route.

# %%
display.Image("Screenshot 2023-12-19 142056.png")

# %% [markdown]
# Q4. Create a "/welcome" route to display the welcome message "Welcome to ABC Corporation" and a "/" route to show the following details:

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route('/')
# def company_info():
#     return '''
#     Company Name: ABC Corporation
#     Location: India
#     Contact Detail: 999-999-9999
#     '''
#
# @app.route('/welcome')
# def welcome():
#     return 'Welcome to ABC Corporation'
#
# if __name__ == '__main__':
#     app.run(host="0.0.0.0")

# %%
display.Image("Screenshot 2023-12-19 142901.png")

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
