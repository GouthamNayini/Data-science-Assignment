# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %%
import pandas as pd
df=pd.read_excel("flight_price.xlsx")
df.shape
#10683 rows,11 columns
# Out:
# (10683, 11)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
import seaborn as sns
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df.describe()
#min is 1759
#max is 79512
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
sns.boxplot(x=df['Price'],y=df['Airline'])
# Out:
# <Axes: xlabel='Price', ylabel='Airline'>

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.
#
# yes outliers are present
# Skewing summary statistics: Outliers can significantly affect summary statistics such as the mean and standard deviation, making them less representative of the central tendency and variability of the data.
# Model performance: Outliers can distort the relationships captured by predictive models, leading to biased estimates and reduced model performance.
# Interpretation of results: Outliers may influence the interpretation of results, particularly in statistical analyses or machine learning models, leading to erroneous conclusions or misleading insights.

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?
#
# Date/Time: Analyze flight prices over time to identify seasonal trends and peak periods.
# Month: Group data by month to observe monthly fluctuations in flight prices.
# Day of the Week: Examine if flight prices vary depending on the day of the week.
# Destination: Investigate whether flight prices vary based on popular destinations and their respective peak seasons.
# Flight Duration: Determine if flight prices correlate with the duration of the flight.
# Airlines: Compare flight prices among different airlines to understand their pricing strategies.

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?
#
# Date/Time: Analyze flight prices over time to identify seasonal trends and peak periods.
# Month: Group data by month to observe monthly fluctuations in flight prices.
# Day of the Week: Examine if flight prices vary depending on the day of the week.
# Destination: Investigate whether flight prices vary based on popular destinations and their respective peak seasons.
# Flight Duration: Determine if flight prices correlate with the duration of the flight.
# Airlines: Compare flight prices among different airlines to understand their pricing strategies.
#
# Visualizations to Use:
# Bar Charts: Compare average flight prices across different months, days of the week, routes, or airlines.
# Box Plots: Display the distribution of flight prices for each month, day of the week, or route.
# Heatmaps: Visualize flight prices as a heatmap, with months and routes on the axes, to highlight price variations.
# Line Plots: Show the trend of flight prices over time for specific routes or airlines.
# Scatter Plots: Explore the relationship between booking lead time and flight prices.

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?
#
#
# Features to Analyze:
# Date/Time: Analyze flight prices over time to identify temporal trends and seasonal variations.
# Route: Investigate how flight prices vary based on different routes, considering factors like distance and demand.
# Airlines: Compare flight prices among different airlines to understand pricing strategies and competitive dynamics.
# Departure and Arrival Cities: Examine flight prices based on the popularity and demand for specific routes.
# Booking Lead Time: Determine if flight prices correlate with the timing of booking, considering factors like advance booking discounts.
# Flight Duration: Analyze the relationship between flight duration and prices, considering factors like fuel costs.
# Special Events/Holidays: Identify any spikes or fluctuations in flight prices coinciding with major events, holidays, or peak travel seasons.
# Additional Services: Explore the impact of add-on services like seat selection, baggage fees, and in-flight amenities on flight prices.
# Methodology:
# Data Exploration: Begin by exploring the dataset to understand its structure and the distribution of key variables.
# Statistical Analysis: Conduct statistical tests and analyses to quantify the relationship between features and flight prices.
# Visualization: Use visualizations such as scatter plots, box plots, line plots, and heatmaps to visualize the relationships between different features and flight prices.
# Regression Analysis: Perform regression analysis to identify significant predictors of flight prices and their impact on pricing strategies.
# Feature Importance: Determine the importance of each feature in predicting flight prices using techniques like feature importance scores.
# Identify Trends and Patterns: Look for recurring patterns or trends in flight prices across different features.
# Key Drivers of Price Variability: Identify the main factors driving variability in flight prices and their relative importance.
# Presentation to Management Team:
# Introduction: Provide background information on the analysis objective and methodology.
# Data Overview: Present key statistics and visualizations describing the dataset, including the distribution of flight prices and relevant features.
# Factors Affecting Flight Prices: Discuss the main factors identified through the analysis, highlighting their impact on flight prices.
# Temporal Trends: Present time series plots showing the trend of flight prices over time and discuss any seasonal patterns or trends.
# Route Analysis: Compare flight prices across different routes, highlighting routes with the highest and lowest prices.
# Airlines Comparison: Compare flight prices among different airlines, discussing pricing strategies and competitive dynamics.
# Booking Lead Time Analysis: Examine the relationship between booking lead time and flight prices, providing insights into advance booking discounts.
# Special Events/Holidays: Discuss any spikes or fluctuations in flight prices coinciding with major events, holidays, or peak travel seasons.
# Recommendations: Based on the analysis, provide actionable recommendations for pricing strategies, route optimization, and marketing campaigns to optimize revenue and profitability.

# %% [markdown]
# Google playstore

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1.shape
#10841 Rows
#13 Columnns
# Out:
# (10841, 13)

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Drop rows with missing values in the Rating and Category columns
df1.dropna(subset=['Rating', 'Category'], inplace=True)

# Create a boxplot using Seaborn
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Rating', data=df1, palette='viridis')
plt.title('App Ratings by Category')
plt.xlabel('Category')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Goutham\AppData\Local\Temp\ipykernel_19044\1510237786.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Category', y='Rating', data=df1, palette='viridis')

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %% [markdown]
# There are minimal null values in Content Rating,Current Ver,Android Ver
# as minimal null values doesnt impact much we can remove

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset from the URL
url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
df = pd.read_csv(url)

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Size'], df['Rating'], alpha=0.5, color='blue')
plt.title('Relationship between App Size and Rating')
plt.xlabel('App Size (KB)')
plt.ylabel('Rating')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Clean the Price column by removing the dollar sign and converting to numeric
df1['Price'] = df1['Price'].apply(lambda x: float(x.replace('$', '')) if '$' in str(x) else 0)

# Group by Type and calculate the average price for each group
avg_prices = df1.groupby('Type')['Price'].mean()

# Create a bar chart
plt.figure(figsize=(8, 6))
avg_prices.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Average Prices by App Type')
plt.xlabel('App Type')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
import pandas as pd

# Load the dataset from the URL
url = "https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv"
df = pd.read_csv(url)

# Clean the Installs column by removing non-numeric characters and converting to numeric
df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '')
df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce')

# Drop rows with missing values in the Installs column
df.dropna(subset=['Installs'], inplace=True)

# Group by App and sum the installs, then sort by the sum in descending order
app_installs = df.groupby('App')['Installs'].sum().sort_values(ascending=False)

# Select the top 10 most popular apps
top_10_apps = app_installs.head(10)

# Display the frequency table
print("Top 10 Most Popular Apps by Number of Installs:")
print(top_10_apps)
# Out:
# Top 10 Most Popular Apps by Number of Installs:
# App
# Subway Surfers                  6.000000e+09
# Google News                     4.000000e+09
# Hangouts                        4.000000e+09
# Google Drive                    4.000000e+09
# Google Photos                   4.000000e+09
# Instagram                       4.000000e+09
# Candy Crush Saga                3.500000e+09
# Maps - Navigate & Explore       3.000000e+09
# Google Chrome: Fast & Secure    3.000000e+09
# WhatsApp Messenger              3.000000e+09
# Name: Installs, dtype: float64

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?
#
#
#
# To identify the most popular app categories on the Google Play Store, you can follow these steps:
#
# Data Exploration: Start by exploring the Google Play Store dataset to understand its structure and the information it contains. This includes examining the columns available and understanding their meanings.
#
# Analysis of App Categories: Analyze the distribution of apps across different categories. You can do this by counting the number of apps in each category and visualizing the distribution using histograms, pie charts, or bar charts.
#
# Popularity Based on Installs: Analyze the popularity of app categories based on the number of installs. Calculate the total installs for each category, and identify which categories have the highest total installs.
#
# User Ratings: Consider the average user ratings for apps in each category. Higher-rated categories may indicate higher user satisfaction and popularity.
#
# Reviews: Analyze the number of reviews for apps in each category. Categories with a high number of reviews may indicate high user engagement and popularity.
#
# Price Distribution: Analyze the distribution of app prices across different categories. Categories with a higher proportion of free or lower-priced apps may attract more users.
#
# Trends Over Time: Investigate whether the popularity of app categories has changed over time. Analyze trends in app category preferences to identify emerging or declining categories.
#
# Competitive Analysis: Consider the level of competition within each category. Evaluate the number of apps and the market saturation in each category to assess the potential challenges and opportunities for the new app.

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?
#
# Features to Analyze:
#
# Number of Apps: Count the total number of apps developed by each developer.
# Total Installs: Sum the number of installs for all apps developed by each developer.
# Average Ratings: Calculate the average ratings of apps developed by each developer.
# Reviews: Sum the total number of reviews for all apps developed by each developer.
# App Categories: Analyze the distribution of app categories developed by each developer.
# Data Visualizations:
#
# Bar Chart: Compare the number of apps developed by each developer.
# Bar Chart or Scatter Plot: Show the total installs for each developer.
# Bar Chart or Box Plot: Display the average ratings of apps developed by each developer.
# Bar Chart or Scatter Plot: Present the total number of reviews for each developer.
# Stacked Bar Chart or Pie Chart: Visualize the distribution of app categories developed by each developer.

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?
#
#
# Features to Analyze:
#
# App Release Dates: Analyze the frequency of app releases over time.
# Installs Over Time: Examine the trend of app installs over time.
# Ratings Over Time: Investigate the trend of app ratings over time.
# Reviews Over Time: Analyze the trend of app reviews over time.
# Data Visualizations:
#
# Line Plot: Show the number of app releases over time to identify any seasonal patterns or trends.
# Line Plot: Display the trend of app installs over time to identify peak periods.
# Line Plot or Box Plot: Present the trend of app ratings over time to understand user satisfaction levels.
# Line Plot or Bar Chart: Visualize the trend of app reviews over time to identify periods of high user engagement or feedback.
