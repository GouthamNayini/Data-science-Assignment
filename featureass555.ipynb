# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %%
import numpy as np

# Sample data
time_studied = np.array([10, 8, 12, 15, 7])
exam_scores = np.array([85, 75, 90, 95, 70])

# Calculate Pearson correlation coefficient
pearson_corr = np.corrcoef(time_studied, exam_scores)[0, 1]

print("Pearson Correlation Coefficient:", pearson_corr)
# Out:
# Pearson Correlation Coefficient: 0.9691854251635827

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.

# %%
import scipy.stats as stats

# Sample data
sleep = [7, 8, 6, 5, 8]
job_satisfaction = [8, 9, 7, 6, 9]

# Calculate Spearman's rank correlation coefficient
spearman_corr, _ = stats.spearmanr(sleep, job_satisfaction)

print("Spearman's Rank Correlation Coefficient:", spearman_corr)
# Out:
# Spearman's Rank Correlation Coefficient: 1.0

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.

# %%
# Sample data
exercise_hours = [3, 5, 2, 4, 6]
bmi = [24, 26, 28, 23, 30]

# Calculate Pearson correlation coefficient
pearson_corr_exercise_bmi = np.corrcoef(exercise_hours, bmi)[0, 1]

# Calculate Spearman's rank correlation coefficient
spearman_corr_exercise_bmi, _ = stats.spearmanr(exercise_hours, bmi)

print("Pearson Correlation Coefficient between Exercise Hours and BMI:", pearson_corr_exercise_bmi)
print("Spearman's Rank Correlation Coefficient between Exercise Hours and BMI:", spearman_corr_exercise_bmi)
# Out:
# Pearson Correlation Coefficient between Exercise Hours and BMI: 0.33129457822453956
# Spearman's Rank Correlation Coefficient between Exercise Hours and BMI: 0.3

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.

# %%
import pandas as pd

# Create a DataFrame with sample data
data = pd.DataFrame({
    "Hours Watching TV": [2, 4, 1, 3, 0.5, 5, 0, 3.5],
    "Physical Activity Level": [2, 1, 3, 2, 3, 1, 3, 2]
})

# Calculate the Pearson correlation coefficient
correlation = data["Hours Watching TV"].corr(data["Physical Activity Level"])

# Print the result
print("Pearson correlation coefficient:", correlation)
# Out:
# Pearson correlation coefficient: -0.9455146717828623

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame with the survey results
data = {
    "Age (Years)": [25, 42, 37, 19, 31, 28],
    "Soft Drink Preference": ["Coke", "Pepsi", "Mountain Dew", "Coke", "Pepsi", "Coke"]
}

df = pd.DataFrame(data)

# Create a frequency table
frequency_table = pd.crosstab(df['Soft Drink Preference'], pd.cut(df['Age (Years)'], bins=[18, 25, 35, 45]))

# Plot the frequency of soft drink preferences across different age groups
frequency_table.plot(kind='bar', figsize=(10, 6))
plt.title('Soft Drink Preferences by Age Group')
plt.xlabel('Soft Drink Preference')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.legend(title='Age Group')

plt.show()

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.

# %%
import numpy as np

# Generate random numbers for sales calls and sales
sales_calls = np.random.randint(10, 50, 30)  # 30 random integers between 10 and 50
sales = np.random.randint(1, 10, 30)  # 30 random integers between 1 and 10
pearson_corr_sales = np.corrcoef(sales_calls, sales)[0, 1]

print("Pearson Correlation Coefficient between Sales Calls per Day and Sales per Week:", pearson_corr_sales)
# Out:
# Pearson Correlation Coefficient between Sales Calls per Day and Sales per Week: -0.09584110415683508
